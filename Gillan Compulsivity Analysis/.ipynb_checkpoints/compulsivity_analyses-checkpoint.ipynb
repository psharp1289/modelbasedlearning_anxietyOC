# %% [markdown]
# # Relationships between Factors & State Transition Learning
#
# - view distributions of computational parameters of interest -- Mb beta & state transition learning rate

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from numpy.polynomial.polynomial import polyfit

from scipy.stats import skewtest as skew
from scipy.stats import shapiro
from scipy.stats import ttest_ind as tt
from scipy.stats import pearsonr as corrp
from scipy.stats import pearsonr as corr
import numpy as np
from statsmodels.graphics.gofplots import qqplot

font = {'family' : 'sans-serif',
        'weight' : 'light',
        'size'   : 16}

matplotlib.rc('font', **font)
bad_indices=[]
sr_data=pd.read_csv('self_report_study2.csv') #load self-report data
mb_agnostic=pd.read_csv('mb_scores_rares_empirical_best.csv')
mb_scores=mb_agnostic['MB_behav']

#comp params
state_t=pd.read_csv('Gillan_da_full_lrT_decay.csv',header=None) #load state transition lrs
z,p=skew(state_t)
print('{},{}'.format(z,p))
it_mb=pd.read_csv('Gillan_da_full_MB_decay.csv',header=None) #load MB beta
z,p=skew(it_mb)
print('{},{}'.format(z,p))
mf1=pd.read_csv('Gillan_da_full_mf1_decay.csv',header=None)
z,p=skew(mf1)
print('{},{}'.format(z,p))
mf2=pd.read_csv('Gillan_da_full_mf2_decay.csv',header=None)
z,p=skew(mf2)
print('{},{}'.format(z,p))
lr1=pd.read_csv('Gillan_da_full_lr1_decay.csv',header=None)
z,p=skew(lr1)
print('{},{}'.format(z,p))
mf_2ndstage=pd.read_csv('Gillan_da_full_2ndstage_decay.csv',header=None)
z,p=skew(mf_2ndstage)
print('{},{}'.format(z,p))
st=pd.read_csv('Gillan_da_full_st_decay.csv',header=None)
z,p=skew(st)
print('{},{}'.format(z,p))
mf1a=pd.read_csv('Gillan_da_full_dec_decay.csv',header=None)
z,p=skew(mf1a)
print('{},{}'.format(z,p))
print('')
print('state transition LR mean: {}, sd: {}'.format(np.mean(state_t[0]),np.std(state_t[0])))
f2_low_lr=[]
f2_low_mb=[]
f2_high_lr=[]
f2_high_mb=[]
f2_low_mba=[]
f2_high_mba=[]
sr_data_r=sr_data
fac1=sr_data_r['Factor1']
fac2=sr_data_r['Factor2']
fac3=sr_data_r['Factor3']
print('mean MB agnostic score: {}, sd: {}'.format(np.mean(mb_scores),np.std(mb_scores)))
bad_rows=[]
low_mb=[]


high_lr_mbbeta=[]
high_lr_mbscores=[]
for i in range(len(fac2)):


    if (it_mb[0][i]<2.5):
        bad_rows.append(i)
        

state_t = state_t.drop(labels=bad_rows)
state_t = state_t.reset_index(drop=True)
it_mb = it_mb.drop(labels=bad_rows)
it_mb = it_mb.reset_index(drop=True)
mf1 = mf1.drop(labels=bad_rows)
mf1 = mf1.reset_index(drop=True)
mf2 = mf2.drop(labels=bad_rows)
mf2 = mf2.reset_index(drop=True)
# mf = mf.drop(labels=bad_rows)
# mf = mf.reset_index(drop=True)
lr1 = lr1.drop(labels=bad_rows)
lr1 = lr1.reset_index(drop=True)
st = st.drop(labels=bad_rows)
st = st.reset_index(drop=True)
mf1a = mf1a.drop(labels=bad_rows)
mf1a = mf1a.reset_index(drop=True)
mb_scores = mb_scores.drop(labels=bad_rows)
mb_scores = mb_scores.reset_index(drop=True)
import scipy
# print(scipy.stats.beta.fit(state_t[0],floc=0,fscale=1))
# print(scipy.stats.gamma.fit(it_mb[0],floc=0,fscale=1))


fac2r=fac2.drop(labels=bad_rows)
fac2r = fac2r.reset_index(drop=True)
# fac2r=np.log(fac2r+2.65)
above_2_high=[]
above_2_low=[]


        

for i in range(len(fac2r)):

    if fac2r[i]>=1.0:
            f2_high_lr.append(state_t[0][i])
            f2_high_mb.append(it_mb[0][i])
            f2_high_mba.append(mb_scores[i])
            if state_t[0][i]>0.094:
                above_2_high.append(state_t[0][i])
    elif fac2r[i]<=-1:
            if state_t[0][i]>0.094:
                above_2_low.append(state_t[0][i])
            f2_low_lr.append(state_t[0][i])
            f2_low_mb.append(it_mb[0][i])
            f2_high_mba.append(mb_scores[i])
        
# lr1=np.log(lr1)


# state_t=state_t+1
print('')
print('median MB {}'.format(np.median(it_mb)))
data=it_mb[0]
# First quartile (Q1)
Q1 = np.percentile(data, 25, interpolation = 'midpoint')
  
# Third quartile (Q3)
Q3 = np.percentile(data, 75, interpolation = 'midpoint')
  
# Interquaritle range (IQR)
IQR = Q3 - Q1
print('Q1:{}, Q3:{}, IQR: {}'.format(Q1,Q3,IQR))
print('Q3+1.5*IQR = {}'.format(Q3+1.5*IQR))
print('median MF1 {}'.format(np.median(mf1)))
print('median MF2 {}'.format(np.median(mf2)))
print('median lr {}'.format(np.median(lr1)))
print('median st {}'.format(np.mean(st)))
print('median decay {}'.format(np.median(mf1a)))
it_mb[0]=[it_mb[0][i]/lr1[0][i] for i in range(len(lr1))]
print('')
print('MINIMUM RE-SCALED MB BETA: {}'.format(np.min(it_mb)))
print('')
it_mb=np.log(it_mb)
state_t=np.log(state_t)
print('')
print('low MB performers compulsivity scores: {}'.format(low_mb))
print('median low comp: {}, median high comp state LR: {}'.format(np.median(f2_low_lr),np.median(f2_high_lr)))

print('mean low comp: {}, mean high comp state LR: {}'.format(np.mean(f2_low_lr),np.mean(f2_high_lr)))
print('mean low comp: {}, mean high comp MB-beta: {}'.format(np.mean(f2_low_mb),np.mean(f2_high_mb)))
# print('')
# print('percentage high comp above mean TL : {}'.format(len(above_2_high)/len(f2_high_lr)))
# print('percentage low above mean TL : {}'.format(len(above_2_low)/len(f2_low_lr)))
# print('')

print('mean: {}, sd: {} of TL full sample'.format(np.mean(state_t[0]),np.std(state_t[0])))
print('')
print('mean: {}, sd: {} of compulsivity full sample'.format(np.mean(fac2),np.std(fac2)))
print('mean: {}, sd: {} of compulsivity reduced sample'.format(np.mean(fac2r),np.std(fac2r)))

t,p=tt(fac2,fac2r,equal_var=False)
print('difference in compulsivity before after t: {}, p:{}'.format(t,p))
print('here')
print(mf[0][1])
print('here')
print(len(it_mb[0]))
print('here')
ratio_mfmb=[(it_mb[0][i]-mf[0][i])/ (mf[0][i]+it_mb[0][i]) for i in range(len(it_mb[0]))]
print('B-MF median: {}'.format(np.median(mf1)))
print('B-MF mean: {}'.format(np.mean(mf1[0])))

fac1=fac1.drop(labels=bad_rows)
fac3=fac3.drop(labels=bad_rows)
sr_data= sr_data.drop(labels=bad_rows)
sr_data =sr_data.reset_index(drop=True)

# print('mean: {}, sd: {} of compulsivity small sample'.format(np.mean(fac2_r),np.std(fac2_r)))
r,p=corrp(mb_scores,state_t[0])
print('model agnostic scores and state_t: {}, pval: {}'.format(r,p))
r,p=corrp(mb_scores,it_mb[0])
print('model agnostic scores and MB beta: {}, pval: {}'.format(r,p))
r,p=corrp(mb_scores,lr1[0])
print('model agnostic scores and decay rate: {}, pval: {}'.format(r,p))
r,p=corrp(state_t[0],lr1[0])
print('state TL and decay rate: {}, pval: {}'.format(r,p))

r,p=corrp(it_mb[0],state_t[0])
print('MB beta and state_t: {}, pval: {}'.format(r,p))

lrt_r=state_t
corr_fac1=sr_data_r['Factor1'].corr(np.log(lrt_r[0]))
print(corr_fac1)
iq=sr_data_r['iq']
corr_fac2=sr_data_r['Factor2'].corr(np.log(lrt_r[0]))
print(corr_fac2)
corr_fac3=sr_data_r['Factor3'].corr(np.log(lrt_r[0]))
print(corr_fac3)

sns.scatterplot(x=fac2r,y=state_t[0])
plt.ylabel('State Transition Learning ')
plt.xlabel('Compulsivity')
plt.show()

sns.scatterplot(x=fac2r,y=mf[0])
plt.ylabel('MF  ')
plt.xlabel('Compulsivity')
plt.show()

sns.scatterplot(x=fac2r,y=lr1[0])
plt.ylabel('LR DECAY ')
plt.xlabel('Compulsivity')
plt.show()

sns.scatterplot(x=fac2r,y=ratio_mfmb)
plt.ylabel('ratio mfmb ')
plt.xlabel('Compulsivity')
plt.show()

sns.scatterplot(x=state_t[0],y=it_mb[0])
plt.ylabel('MB Beta ')
plt.xlabel('State T')
# plt.savefig('MBbeta_STLR_regularspace.png',bbox_inches='tight',dpi=300)
plt.show()
r,p=corr(state_t[0],it_mb[0])
print('corr LR and MB : {}, pval {}'.format(r,p))
sns.scatterplot(x=fac2r,y=it_mb[0])
plt.ylabel('(log) MB Beta ')
plt.xlabel('Compulsivity')
plt.show()
sns.scatterplot(x=fac2r,y=mb_scores)
plt.ylabel('MB ma')
plt.xlabel('Compulsivity')

plt.show()

from mpl_toolkits.mplot3d import Axes3D

sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
df=pd.DataFrame()
df['compulsivity']=fac2r
df['model agnostic']=mb_scores
df['TL']=state_t
x =df['compulsivity']
y = df['model agnostic']
z = df['TL']

ax.set_xlabel("Compulsivity")
ax.set_ylabel("MA")
ax.set_zlabel("TL")

ax.scatter(x, y, z)

plt.show()


fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
df=pd.DataFrame()
df['compulsivity']=fac2r
df['mb beta']=it_mb
df['TL']=state_t
x =df['compulsivity']
y = df['mb beta']
z = df['TL']

ax.set_xlabel("Compulsivity")
ax.set_ylabel("MB_Beta")
ax.set_zlabel("TL")

ax.scatter(x, y, z)

plt.show()


sns.scatterplot(x=it_mb[0],y=mb_scores)
b, m = polyfit(it_mb[0], mb_scores, 1)
plt.plot(it_mb[0], mb_scores, '.')
plt.plot(it_mb[0], b + m * it_mb[0], '-')
plt.ylabel('MB MA')
plt.xlabel('MB beta')
plt.ylim(0.01,1)
# plt.savefig('mbHigh_modelagnosticMB_mbBeta.png', dpi=300,bbox_inches='tight')
plt.show()
sns.scatterplot(x=state_t[0],y=mb_scores)
b, m = polyfit(state_t[0], mb_scores, 1)
plt.plot(state_t[0], mb_scores, '.')
plt.plot(state_t[0], b + m * state_t[0], '-')
plt.ylabel('Model Agnostic MB Scores')
plt.xlabel('LR')
plt.ylim(0.01,1)
# plt.savefig('mbHigh_modelagnosticMB_learningRate.png', dpi=300,bbox_inches='tight')
plt.show()
stat,p=shapiro(lrt_r[0])
print("TL normality test: {} , p-val: {}".format(stat,p))
# q-q plot
print('qq plot lr transition')
qqplot(lrt_r[0], line='s')
plt.show()
print('qq plot mb beta')
qqplot(it_mb[0], line='s')
plt.show()
stat,p=shapiro(it_mb[0])
print("MB normality test: {} , p-val: {}".format(stat,p))
qqplot(mf1[0], line='s')
plt.show()
stat,p=shapiro(mf1[0])
print("mf1 normality test: {} , p-val: {}".format(stat,p))
qqplot(mf2[0], line='s')
plt.show()
stat,p=shapiro(mf2[0])
print("Mf2 normality test: {} , p-val: {}".format(stat,p))
qqplot(lr1[0], line='s')
plt.show()
stat,p=shapiro(lr1[0])
print("LR1 normality test: {} , p-val: {}".format(stat,p))
# qqplot(lr2[0], line='s')
# plt.show()
# stat,p=shapiro(lr2[0])
# print("LR2 normality test: {} , p-val: {}".format(stat,p))
qqplot(mf1a[0], line='s')
plt.show()
stat,p=shapiro(mf1a[0])
print("MF1a normality test: {} , p-val: {}".format(stat,p))
# Out:
# [23.72262007],[2.10688497e-124]
# [24.27079565],[3.98902112e-130]
# [26.06365988],[9.41948763e-150]
# [16.66674565],[2.28712477e-62]
# [-12.86659565],[6.93939069e-38]
# [4.91582745],[8.8408241e-07]
# [-1.58785938],[0.11231814]
# [10.05888385],[8.39446259e-24]
#
# state transition LR mean: 0.11651707324840764, sd: 0.05216625179413975
# mean MB agnostic score: 0.4514455726438624, sd: 0.10540172500405216
#
# median MB 6.1818
# Q1:3.6527, Q3:10.815999999999999, IQR: 7.1633
# Q3+1.5*IQR = 21.56095
# median MF1 0.14514000000000002
# median MF2 1.214
# median lr 0.8271200000000001
# median st 0    1.003914
# dtype: float64
# median decay 0.27918000000000004
#
# MINIMUM RE-SCALED MB BETA: 0    2.642812
# dtype: float64
#
#
# low MB performers compulsivity scores: []
# median low comp: 0.066218, median high comp state LR: 0.090121
# mean low comp: 0.07200341803278688, mean high comp state LR: 0.1076587659574468
# mean low comp: 10.699954098360655, mean high comp MB-beta: 6.648387234042556
# ...

# %% [markdown]
# # Full sample regression after transforming compulsivity and mb beta to ensure homoscedasticity and normality of residuals

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from scipy import stats
import statsmodels.stats.api as sms
import statsmodels.api as sm
from scipy.stats import gamma
from statsmodels.compat import lzip



font = {'family' : 'sans-serif',
        'weight' : 'light',
        'size'   : 10}


matplotlib.rc('font', **font)



X=pd.DataFrame()
X = sr_data[['iq','gender','age']]
X['State Transition Learning']=state_t[0]

X = sm.add_constant(X)

y=fac2r
ests = sm.OLS(y, X)
estf = ests.fit()
print(estf.summary())

X=pd.DataFrame()
X = sr_data[['iq','gender','age']]
X['MB Beta']=it_mb[0]

X = sm.add_constant(X)

y=fac2r
ests = sm.OLS(y, X)
estf = ests.fit()
print(estf.summary())

X=pd.DataFrame()
X = sr_data[['iq','gender','age']]
X['MB Beta']=it_mb[0]
X['State Transition Learning']=state_t[0]
X = sm.add_constant(X)

y=fac2r
ests = sm.OLS(y, X)
estf = ests.fit()
print(estf.summary())

# name = ['Lagrange multiplier statistic', 'p-value',
#         'f-value', 'f p-value']
# sm.stats.diagnostic.het_white(estf.resid, estf.model.exog)
# print(lzip(name, test))
# fig = sm.graphics.plot_regress_exog(estf, "it_mb res")
# fig.tight_layout(pad=1.0)
# # plt.savefig('heteroscedasticity_itmb_red.jpg',bbox_inches='tight',dpi=300)
# plt.show()
# fig = sm.graphics.plot_regress_exog(estf, "State Transition Learning Rate res")
# fig.tight_layout(pad=1.0)
# # plt.savefig('heteroscedasticity_lr_red.jpg',bbox_inches='tight',dpi=300)

# plt.show()
# from scipy import stats
# res = estf.resid # residuals
# fig = sm.qqplot(res, stats.t, fit=True, line="45")
# plt.show()
# #build design matrix
print('Lrate Predicts Model-Basedness')
# X = sr_data[['iq','gender','age']]
#########COMMENT

X=pd.DataFrame()
# X = sr_data[['iq','gender','age']]
X['lrate_transition']=state_t[0]
X['it_mb']=it_mb[0]
# X['mf1']=mf1[0]
# X['mf2']=mf2[0]
# X['lr1']=lr1[0]
# X['lr2']=lr2[0]
# X['mf1a']=mf1a[0]
# X['st']=st[0]
X = sm.add_constant(X)
y=mb_scores
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
print('')
print('')

X=pd.DataFrame()
# X = sr_data[['iq','gender','age']]
X['lrate_transition']=state_t[0]
# X['mf1']=mf1[0]
# X['mf2']=mf2[0]
# X['lr1']=lr1[0]
# X['lr2']=lr2[0]
# X['mf1a']=mf1a[0]
# X['st']=st[0]
X = sm.add_constant(X)
y=mb_scores
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
print('')
print('')

X=pd.DataFrame()
# X = sr_data[['iq','gender','age']]
X['it_mb']=it_mb[0]
# X['mf1']=mf1[0]
# X['mf2']=mf2[0]
# X['lr1']=lr1[0]
# X['lr2']=lr2[0]
# X['mf1a']=mf1a[0]
# X['st']=st[0]
X = sm.add_constant(X)
y=mb_scores
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
print('')
print('')
r,p=corrp(mb_scores,state_t[0])
print('model agnostic scores and state_t: {}, pval: {}'.format(r,p))
print('')



X=pd.DataFrame()
X = sr_data[['iq','gender','age']]
X['MB Agnostic']=mb_scores
X = sm.add_constant(X)
y=fac2r
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
print('')
print('')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Factor2   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     9.067
# Date:                Thu, 24 Jun 2021   Prob (F-statistic):           5.07e-07
# Time:                        00:04:37   Log-Likelihood:                -512.41
# No. Observations:                 409   AIC:                             1035.
# Df Residuals:                     404   BIC:                             1055.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         1.3039      0.503      2.590      0.010       0.314       2.294
# ...

# %% [markdown]
# # plotting relationships

# %%
from scipy.stats import pearsonr as corr
sns.scatterplot(x=resid_mb,y=fac2r)
b, m = polyfit(resid_mb, fac2r, 1)
plt.plot(resid_mb, fac2r, '.')
plt.plot(resid_mb, b + m * resid_mb, '-')
plt.ylabel('compulsivity')
plt.xlabel('MB beta resid')
plt.show()

sns.scatterplot(x=it_mb[0],y=fac2r)
b, m = polyfit(it_mb[0], fac2r, 1)
plt.plot(it_mb[0], fac2r, '.')
plt.plot(it_mb[0], b + m * it_mb[0], '-')
plt.ylabel('compulsivity')
plt.xlabel('MB beta')
plt.show()

residmb_log=resid_mb

itmb_log=np.log(it_mb[0])
sns.scatterplot(x=residmb_log,y=fac2r)
b, m = polyfit(residmb_log, fac2r, 1)
plt.plot(residmb_log, fac2r, '.')
plt.plot(residmb_log, b + m * residmb_log, '-')
plt.ylabel('compulsivity')
plt.xlabel('MB beta resid LOG')
plt.show()

sns.scatterplot(x=itmb_log,y=fac2r)
b, m = polyfit(itmb_log, fac2r, 1)
plt.plot(itmb_log, fac2r, '.')
plt.plot(itmb_log, b + m * itmb_log, '-')
plt.ylabel('compulsivity')
plt.xlabel('MB beta LOG')
plt.show()


sns.scatterplot(x=resid_tl,y=fac2r)
b, m = polyfit(resid_tl, fac2r, 1)
plt.plot(resid_tl, fac2r, '.')
plt.plot(resid_tl, b + m * resid_tl, '-')
plt.ylabel('compulsivity')
plt.xlabel('LR resid')
plt.show()

sns.scatterplot(x=state_t[0],y=fac2r)
b, m = polyfit(state_t[0], fac2r, 1)
plt.plot(state_t[0], fac2r, '.')
plt.plot(state_t[0], b + m * state_t[0], '-')
plt.ylabel('compulsivity')
plt.xlabel('LR')
plt.show()

residmb_log=resid_tl

itmb_log=state_t[0]
sns.scatterplot(x=residmb_log,y=fac2r)
b, m = polyfit(residmb_log, fac2r, 1)
plt.plot(residmb_log, fac2r, '.')
plt.plot(residmb_log, b + m * residmb_log, '-')
plt.ylabel('compulsivity')
plt.xlabel('LR resid LOG')
plt.show()

sns.scatterplot(x=itmb_log,y=fac2r)
b, m = polyfit(itmb_log, fac2r, 1)
plt.plot(itmb_log, fac2r, '.')
plt.plot(itmb_log, b + m * itmb_log, '-')
plt.ylabel('compulsivity')
plt.xlabel('LR LOG')
plt.show()

logresid_mb=resid_mb
logresid_tl=resid_tl

sns.scatterplot(x=logresid_mb,y=logresid_tl)
b, m = polyfit(logresid_mb, logresid_tl, 1)
plt.plot(logresid_mb, logresid_tl, '.')
plt.plot(logresid_mb, b + m * logresid_mb, '-')
plt.ylabel('lr resid LOG')
plt.xlabel('mb resid LOG')
plt.show()

r,p=corr(logresid_mb, logresid_tl)
print('correlation residual mb and residual trasnition LR : {} , pval:{}'.format(r,p))
# Out:
# correlation residual mb and residual trasnition LR : 0.5091884134875868 , pval:3.1179439486759104e-28

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=3)
x=np.asarray(state_t)
xp = polynomial_features.fit_transform(x)
mb_agnostic2=pd.read_csv('mb_scores_simdecay.csv')
mb_scores2=mb_agnostic2['mb_ma']
lr_sim=mb_agnostic2['lr']
lrs2=np.log(lr_sim)
itmb_sim=mb_agnostic2['it']
itmb2=np.log(itmb_sim)
font = {'family' : 'sans-serif',
        'weight' : 'light',
        'size'   : 14}


matplotlib.rc('font', **font)
#build design matrix
print('Lrate Predicts Compulsivity')
X=pd.DataFrame()
X['State Transition Learning Rate (log)']=state_t[0]
X['Model-Based Beta (log)']=it_mb[0]

X['Model Basedness']=mb_scores
sns.set(style="white",
        palette="muted",
        color_codes=True,
       font_scale=1.3)

p = sns.regplot(x="Model-Based Beta (log)", y="Model Basedness",marker='.', data=X,color='mediumorchid',
                line_kws={'color':'black','linewidth':3})
plt.savefig('ITMB_reducedsample_empiricaldata_decay_log.jpg',bbox_inches='tight',dpi=300)
plt.show()

# LR related to model-agnostic measure of MB Control, controlling for MB Beta


#build design matrix
print('Lrate Predicts Compulsivity')
X=pd.DataFrame()

X['lrate_transition']=state_t[0]
X['it_mb']=it_mb[0]
X = sm.add_constant(X)
y=mb_scores
est = sm.OLS(y, X)
este = est.fit()
print(este.summary())
print('')
print('')

#plot regression coefficients
betase=este.params
err_seriese = betase - este.conf_int()[0]
coef_df_e = pd.DataFrame({'coef': betase.values[1:],
                        'err': err_seriese.values[1:],
                        'varname': err_seriese.index.values[1:]
                       })
print(coef_df_e)
fig, ax = plt.subplots(figsize=(5, 5))
coef_df_e.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)
ax.set_ylabel('')
ax.set_xlabel('')
ax.scatter(x=pd.np.arange(coef_df_e.shape[0]), 
           marker='s', s=120, 
           y=coef_df_e['coef'], color='black')
ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(['LR Transitions', 'MB Beta'], 
                       rotation=0, fontsize=14)
ax.set_title('Empirical Data',size=14)

plt.savefig('empirical_data_regression_params.jpg',dpi=300)
plt.show()
# Out:
# Lrate Predicts Compulsivity
# Lrate Predicts Compulsivity
#                             OLS Regression Results
# ...
# Dep. Variable:               MB_behav   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     101.1
# Date:                Thu, 24 Jun 2021   Prob (F-statistic):           2.33e-36
# Time:                        00:05:36   Log-Likelihood:                 400.18
# No. Observations:                 409   AIC:                            -794.4
# Df Residuals:                     406   BIC:                            -782.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Simulated data post-predictive check

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from matplotlib.lines import Line2D



font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 20}
matplotlib.rc('font', **font)
sns.set_style("white")

polynomial_features= PolynomialFeatures(degree=3)
x=np.asarray(state_t)
xp = polynomial_features.fit_transform(x)
mb_agnostic2=pd.read_csv('mb_scores_simdecay.csv')
mb_scores2=mb_agnostic2['mb_ma']
lr_sim=mb_agnostic2['lr']
lrs2=np.log(lr_sim)
itmb_sim=mb_agnostic2['it']
itmb2=np.log(itmb_sim)

#build design matrix
print('Lrate Predicts Compulsivity')
X=pd.DataFrame()
X['State Transition Learning Rate (log)']=lrs2
X['Model-Based Beta (log)']=itmb2
X['Model Basedness']=mb_scores2

sns.set(style="white",
        palette="muted",
        color_codes=True,
       font_scale=1.3)
p = sns.regplot(x="Model-Based Beta (log)", y="Model Basedness",marker='.', data=X,color='mediumseagreen',
                line_kws={'color':'black','linewidth':3})
plt.savefig('ITMB_reducedsample_simulated_decay_log.jpg',bbox_inches='tight',dpi=300)
plt.show()

# LR related to model-agnostic measure of MB Control, controlling for MB Beta


#build design matrix
print('Lrate Predicts Compulsivity')
X=pd.DataFrame()

X['lrate_transition']=lrs2
X['it_mb']=itmb2
X = sm.add_constant(X)
y=mb_scores2
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
print('')
print('')


grouping=['Simulated']*2+['Empirical']*2

#plot regression coefficients
betas=est2.params
err_series = betas - est2.conf_int()[0]
coef_df = pd.DataFrame({'coef': betas.values[1:].tolist()+betase.values[1:].tolist(),
                        'err': err_series.values[1:].tolist()+err_seriese.values[1:].tolist(),
                        'varname': err_series.index.values[1:].tolist()+err_seriese.index.values[1:].tolist(),
                        'group':grouping

                       })
print(coef_df)

sns.set(style="white",
        palette="muted",
        color_codes=True,
       font_scale=0.95)
fig, ax = plt.subplots(figsize=(5, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none',legend=False,
             yerr='err')

ax.set_ylabel('')
ax.set_xlabel('')
ax.scatter(x=[0,1], 
           marker='s', s=120, 
           y=betas.values[1:].tolist(),color='mediumseagreen')
ax.scatter(x=[2,3], 
           marker='s', s=120, 
           y=betase.values[1:].tolist(),color='mediumorchid')

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(['LR-T', 'MB Beta','LR-T ', 'MB Beta '], 
                       rotation=0, fontsize=14)
ax.set_title('Regression Beta Weights',size=14)
custom_lines = [Line2D([0], [0], color='mediumseagreen', lw=4),
                Line2D([0], [0], color='mediumorchid', lw=4)]


ax.legend(custom_lines, ['Simulated', 'Empirical'],loc='upper left')
plt.ylabel('Regression Beta Weights',fontsize=15)
plt.title('')
plt.savefig('simulated_and_empirical_data_regression_params.jpg',bbox_inches='tight',dpi=300)
plt.show()
print(coef_df.shape[0])
# Out:
# Lrate Predicts Compulsivity
# Lrate Predicts Compulsivity
#                             OLS Regression Results
# ...
# Dep. Variable:                  mb_ma   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     82.44
# Date:                Wed, 23 Jun 2021   Prob (F-statistic):           1.14e-30
# Time:                        12:11:11   Log-Likelihood:                 440.21
# No. Observations:                 400   AIC:                            -874.4
# Df Residuals:                     397   BIC:                            -862.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Model Comparison Results

# %%
from brokenaxes import brokenaxes
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 14}
matplotlib.rc('font', **font)
sns.set_style("white")


f, axs = plt.subplots(6, 1,figsize=(10,10),gridspec_kw={'height_ratios':[10,10,30,20,10,40]},sharex=False)

Daw_TL=559888.84
winning=550818.84
adjustment_normal_sticky=1521

models=['1AV + Count']
BIC=[559782.04-winning-adjustment_normal_sticky]
ax1 = sns.barplot(x=BIC, y=models,
                color='k',ax=axs[0])
ax1.set(title='Step 1: Action-value architecture', ylabel="",
       xlabel="\u0394 iBIC compared to Typical no decay")

winning=549224.76 # MC Winning

models=['Typical no decay']
BIC=[549418.23-winning]
ax1 = sns.barplot(x=BIC, y=models,
                 color='k',ax=axs[1])
ax1.set(title='Step 2: Typical no decay vs. ISTL no decay model', ylabel="",
       xlabel="\u0394 iBIC compared to ISTL no decay")

# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
models=['2AV LR + Counterfactual','2AV + Bayes','2AV + Fixed LR']
BIC=[553994.95-winning-adjustment_normal_sticky,553025.44-winning-adjustment_normal_sticky,551612.23-winning-adjustment_normal_sticky]
ax1 = sns.barplot(x=BIC, y=models,
                 color='k',ax=axs[2])
ax1.set(title='Step 3: Types of transition learning', ylabel="",
       xlabel="\u0394 iBIC compared to ISTL no decay")


models=['2AV + Dynamic LR + Intercept','2AV + Dynamic LR']
BIC=[551361.71-winning-adjustment_normal_sticky,551327.21-winning-adjustment_normal_sticky]
ax1 = sns.barplot(x=BIC, y=models,color='k',ax=axs[3])

ax1.set(title='Step 4: Types of incremental learning', ylabel="",
       xlabel="\u0394 iBIC compared to ISTL no decay")
models=['MB',]
BIC=[565698.33-winning-adjustment_normal_sticky]
ax1 = sns.barplot(x=BIC, y=models,color='k',ax=axs[4])
ax1.set(title='Step 5: Model-free learning necessary?', ylabel="",
       xlabel="\u0394 iBIC compared to ISTL no decay")
plt.tight_layout()

winning=525925.988


models=['ISTL no decay', 'Typical','ISTL+one decay','Typical+two decay']
BIC=[549224.76-winning, 536589.12-winning,535866.48-winning,526200.77-winning]
ax1 = sns.barplot(x=BIC, y=models,color='k',ax=axs[5])
ax1.set(title='Step 6: Types of action-value decay?', ylabel="",
       xlabel="\u0394 iBIC compared to ISTL")
plt.tight_layout()

plt.savefig('high_res_model_comparison_final_with_decay.png', dpi=300)
